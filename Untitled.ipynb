# %%
from donkeycar.gym import remote_controller
import numpy as np
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
controller = remote_controller.DonkeyRemoteContoller("kari_sim", "mqtt.eclipse.org")
# Out:
# (clean_session) connecting to broker mqtt.eclipse.org
# connected.
# connecting to broker mqtt.eclipse.org
# connected.

# %%
controller.take_action(action=[1,0.1])

# %%
controller.take_action(action=[0,0])

# %%
ims = []
controller.take_action(action=[-1,0.1])
while True:
    time.sleep(0.1)
    ims.append(controller.observe())
    #controller.take_action([(np.random.rand() - 0.5) * 2, 0.3])
    #im = controller.observe()
    #clear_output(wait = True)
    #print(len(im[(im > 120) * (im < 130)]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-151-14536750f5a5> in <module>
#       2 controller.take_action(action=[-1,0.1])
#       3 while True:
# ----> 4     time.sleep(0.1)
#       5     ims.append(controller.observe())
#       6     #controller.take_action([(np.random.rand() - 0.5) * 2, 0.3])
#
# KeyboardInterrupt:

# %%
len(ims)
# Out:
# 78

# %%
im = controller.observe()

plt.imshow(im)

# %%
for im in ims[50:]:
    im = np.dot(im[...,:3], [0.299, 0.587, 0.114])
    res = []
    for i in range(25):
        #res.append(len(im[(im > i*10) * (im < (i *10 + 10))]))
        #res.append(len(im[im < i]))
        
    out = len(im[(im > 100) * (im < 150)]) < len(im[(im > 150) * (im < 200)])
    plt.figure(1, (10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(res)
    plt.axvline(np.array(res).argmax(), color="r", linestyle="--")
    plt.subplot(1, 2, 2)
    plt.imshow(im)
    plt.show()

# %%
res = []
for i in range(255):
    res.append(len(im[(im > i) * (im < (i + 1))]))
    

plt.plot(res)
# Out:
# 0

# %%
im(im > 1) * (im < 2)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
def calculate_lag(n_times):
    prev = controller.observe()
    l = np.prod(prev.shape)
    ims = []
    times = []
    
    for i in range(n_times):
        time.sleep(0.1)
        ims.append(controller.observe())
        times.append(time.time_ns())
        
    print("Images taken")
    results = []
    for i in range(n_times - 1):
        prev = ims[i]
        cur = ims[i + 1]
        #prev = np.dot(ims[i][...,:3], [0.299, 0.587, 0.114])
        #cur = np.dot(ims[i + 1][...,:3], [0.299, 0.587, 0.114])
        #results.append(len(prev[np.isclose(prev, cur)]))
        results.append(len(prev[prev==cur]))
        

    results = np.array(results)
    time_array = np.array(times[:-1])
    
    differences = np.diff(time_array[results != np.prod(prev.shape)]) / 1e6
    plt.plot(differences)
    return np.mean(differences), differences, times, results

# %%
# %%time
mean, diff, times, results = calculate_lag(100)
print(mean)
# Out:
# Images taken
# 101.43461527551021
# CPU times: user 592 ms, sys: 98.4 ms, total: 690 ms
# Wall time: 10.2 s

# %%
plt.plot(results)

# %%
# %%time
ts = []
for i in range(100):
    
    prev = controller.observe()
    t = time.time_ns()
    l = np.prod(prev.shape)
    while len(prev[prev==controller.observe()]) == l:
        continue
    ts.append((time.time_ns() - t) / 1e6)
# Out:
# CPU times: user 10.2 s, sys: 137 ms, total: 10.3 s
# Wall time: 10 s

# %%
plt.plot(ts)

# %%
np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %%
def image_to_ascii(im):
    asc = []
    chars = ["B","S","#","&","@","$","%","*","!",":","."]
    for j in range(im.shape[1]):
        line = []
        for i in range(im.shape[0]):
            line.append(chars[int(im[i, j]) // 25])
        asc.append("".join(line))

    for line in asc:
        print(line)

# %%
for i
